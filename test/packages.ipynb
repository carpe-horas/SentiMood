# %% [markdown]
# ### 내가 설치한 패키지 numpy=1.26.4 이런 형식으로 출력

# %%
import pkg_resources

# 설치된 패키지 목록 가져오기
installed_packages = {pkg.key: pkg.version for pkg in pkg_resources.working_set}

# 패키지 목록 출력
for package, version in installed_packages.items():
    print(f"{package}={version}")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_9580\69923914.py:1: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# gitpython=3.1.44
# markupsafe=3.0.2
# pyyaml=6.0.2
# sqlalchemy=2.0.38
# aiohappyeyeballs=2.4.6
# aiohttp=3.11.12
# aiosignal=1.3.2
# altair=5.5.0
# annotated-types=0.7.0
# anyio=4.8.0
# asttokens=3.0.0
# async-timeout=4.0.3
# attrs=25.1.0
# blinker=1.9.0
# cachetools=5.5.1
# certifi=2025.1.31
# charset-normalizer=3.4.1
# click=8.1.8
# colorama=0.4.6
# comm=0.2.2
# contourpy=1.3.1
# cycler=0.12.1
# dataclasses-json=0.6.7
# debugpy=1.8.12
# decorator=5.1.1
# distro=1.9.0
# exceptiongroup=1.2.2
# executing=2.1.0
# faiss-cpu=1.10.0
# fonttools=4.56.0
# frozenlist=1.5.0
# gitdb=4.0.12
# greenlet=3.1.1
# h11=0.14.0
# httpcore=1.0.7
# httpx=0.28.1
# httpx-sse=0.4.0
# idna=3.10
# importlib-metadata=8.6.1
# ipykernel=6.29.5
# ipython=8.32.0
# jedi=0.19.2
# jinja2=3.1.5
# jiter=0.8.2
# jsonpatch=1.33
# jsonpointer=3.0.0
# jsonschema=4.23.0
# jsonschema-specifications=2024.10.1
# jupyter-client=8.6.3
# jupyter-core=5.7.2
# kiwisolver=1.4.8
# langchain=0.3.18
# langchain-community=0.3.17
# langchain-core=0.3.34
# langchain-openai=0.3.5
# langchain-text-splitters=0.3.6
# langsmith=0.3.8
# markdown-it-py=3.0.0
# marshmallow=3.26.1
# matplotlib=3.10.0
# matplotlib-inline=0.1.7
# mdurl=0.1.2
# multidict=6.1.0
# mypy-extensions=1.0.0
# narwhals=1.26.0
# nest-asyncio=1.6.0
# numpy=1.26.4
# openai=1.61.1
# orjson=3.10.15
# packaging=24.2
# pandas=2.2.3
# parso=0.8.4
# pickleshare=0.7.5
# pillow=11.1.0
# pip=25.0.1
# platformdirs=4.3.6
# prompt-toolkit=3.0.50
# propcache=0.2.1
# protobuf=5.29.3
# psutil=6.1.1
# pure-eval=0.2.3
# pyarrow=19.0.0
# pydantic=2.10.6
# pydantic-core=2.27.2
# pydantic-settings=2.7.1
# pydeck=0.9.1
# pygments=2.19.1
# pyparsing=3.2.1
# python-dateutil=2.9.0.post0
# python-dotenv=1.0.1
# pytz=2025.1
# pywin32=307
# pyzmq=26.2.1
# referencing=0.36.2
# regex=2024.11.6
# requests=2.32.3
# requests-toolbelt=1.0.0
# rich=13.9.4
# rpds-py=0.22.3
# setuptools=75.8.0
# six=1.17.0
# smmap=5.0.2
# sniffio=1.3.1
# stack-data=0.6.3
# streamlit=1.42.0
# tenacity=9.0.0
# tiktoken=0.8.0
# toml=0.10.2
# tornado=6.4.2
# tqdm=4.67.1
# traitlets=5.14.3
# typing-extensions=4.12.2
# typing-inspect=0.9.0
# tzdata=2025.1
# urllib3=2.3.0
# watchdog=6.0.0
# wcwidth=0.2.13
# wheel=0.45.1
# yarl=1.18.3
# zipp=3.21.0
# zstandard=0.23.0
# autocommand=2.2.2
# backports.tarfile=1.2.0
# inflect=7.3.1
# jaraco.collections=5.1.0
# jaraco.context=5.3.0
# jaraco.functools=4.0.1
# jaraco.text=3.12.1
# more-itertools=10.3.0
# tomli=2.0.1
# typeguard=4.3.0
